# %%
# Import our dependencies
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Read in our dataset
movies_df = pd.read_csv("IMDb movies.csv")
movies_df.head()
# Out:
# C:\Users\bdydh\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# ...

# %%
movies_df

# %%
awards_df = pd.read_csv("awards.csv")
awards_df.head()
# Out:
# C:\Users\bdydh\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      eventId                           eventName      awardName  year  \
# 0  ev0000263  French Syndicate of Cinema Critics  Critics Award  1992
# 1  ev0000263  French Syndicate of Cinema Critics  Critics Award  1992
# 2  ev0000263  French Syndicate of Cinema Critics  Critics Award  1992
# 3  ev0000263  French Syndicate of Cinema Critics  Critics Award  1992
# 4  ev0000263  French Syndicate of Cinema Critics  Critics Award  1992
#
#    occurrence  winAnnouncementTime       categoryName nomeneeNote  \
# 0           1                  NaN          Best Film         NaN
# 1           1                  NaN          Best Film         NaN
# 2           1                  NaN  Best Foreign Film         NaN
# ...

# %%
movies_df[movies_df['imdb_title_id'] == 'tt0101428']
# Out:
#       imdb_title_id               title     original_title  year  \
# 25767     tt0101428  La bella scontrosa  La Belle Noiseuse  1991
#
#       date_published  genre  duration              country  \
# 25767     1991-09-04  Drama       238  France, Switzerland
#
#                       language         director  ...  \
# 25767  French, English, Hebrew  Jacques Rivette  ...
#
#                                                   actors  \
# 25767  Michel Piccoli, Jane Birkin, Emmanuelle Béart,...
#
#                                              description avg_vote votes  \
# 25767  The former famous painter Frenhofer revisits a...      7.7  6820
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 25767     NaN          $ 403056              $ 403056       NaN
#
#       reviews_from_users  reviews_from_critics
# 25767               55.0                  43.0
#
# [1 rows x 22 columns]
